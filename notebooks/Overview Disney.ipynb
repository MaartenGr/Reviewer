# %% [markdown]
# ## Package Overview

# %%
import sys
sys.path.insert(0,'..')
from Disney.scraper import Scraper
from Disney.tfidf import TFIDF
from Disney.cloud import WordCloudGenerator

# %% [markdown]
# **Scrape Data**

# %%
sc = Scraper(dir_path="../", chrome_path="../drivers/chromedriver.exe")
disney_reviews = sc.scrape_disney()

# %% [markdown]
# **Calculate TF-IDF**

# %%
tf = TFIDF(dir_path="../")
tf.generate_disney()

# %% [markdown]
# **Generate Word Cloud**

# %%
wc = WordCloudGenerator(dir_path="../")
image = wc.generate_image(movie="Frozen", word_type="TF-IDF", mask="frozen.jpg", pixels=500, save=False)

# %%
image
# Out:
# <PIL.Image.Image image mode=RGBA size=500x750 at 0x7F8E36B159D0>

# %%
import sys
sys.path.insert(0,'..')
from Reviewer.cloud import WordCloudGenerator

# %%
wc = WordCloudGenerator(dir_path="../")

# %%
result = wc.generate_image(movie="The Good Dinosaur", word_type="TF-IDF", mask="dinosour.jpg", pixels=1200, save=True); result
# Out:
# <PIL.Image.Image image mode=RGB size=1458x1191 at 0x1C0A49F8710>
